# %%
# %%capture
# !pip install "ibm-watsonx-ai==1.0.8" --user
# !pip install "langchain==0.2.11" --user
# !pip install "langchain-ibm==0.1.7" --user
# !pip install "langchain-core==0.2.43" --user

# %%
import os
os._exit(00)

# %%
def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn
warnings.filterwarnings('ignore')

# IBM WatsonX imports
from ibm_watsonx_ai.foundation_models import Model
from ibm_watsonx_ai.metanames import GenTextParamsMetaNames as GenParams
from ibm_watsonx_ai.foundation_models.utils.enums import ModelTypes

from langchain_ibm import WatsonxLLM
from langchain_core.prompts import PromptTemplate, ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough, RunnableSequence
from langchain_core.messages import HumanMessage, SystemMessage
from langchain.chains import LLMChain  # Still using this for backward compatibility

# %%
def llm_model(prompt_txt, params=None):    # This is the code of the program to use outside of this lab where key is known
    
    model_id = "ibm/granite-3-2-8b-instruct"

    default_params = {
        "max_new_tokens": 256,
        "min_new_tokens": 0,
        "temperature": 0.5,
        "top_p": 0.2,
        "top_k": 1
    }

    if params:
        default_params.update(params)

    # Set up credentials for WatsonxLLM
    url = "https://us-south.ml.cloud.ibm.com"
    api_key = "your api key here"
    project_id = "skills-network"

    credentials = {
        "url": url,
        # "api_key": api_key
        # uncomment the field above and replace the api_key with your actual Watsonx API key
    }
    
    # Create LLM directly
    granite_llm = WatsonxLLM(
        model_id=model_id,
        credentials=credentials,
        project_id=project_id,
        params=default_params
    )
    
    response = granite_llm.invoke(prompt_txt)
    return response

# %%
def llm_model(prompt_txt, params=None):
    
    model_id = "ibm/granite-3-2-8b-instruct"

    default_params = {
        "max_new_tokens": 256,
        "min_new_tokens": 0,
        "temperature": 0.5,
        "top_p": 0.2,
        "top_k": 1
    }

    url = "https://us-south.ml.cloud.ibm.com"
    project_id = "skills-network"
    
    granite_llm = WatsonxLLM(
        model_id=model_id,
        project_id=project_id,
        url=url,
        params=default_params
    )
    
    response = granite_llm.invoke(prompt_txt)
    return response

# %%
GenParams().get_example_values()
# Out:
# {'decoding_method': 'sample',
#  'length_penalty': {'decay_factor': 2.5, 'start_index': 5},
#  'temperature': 0.5,
#  'top_p': 0.2,
#  'top_k': 1,
#  'random_seed': 33,
#  'repetition_penalty': 2,
#  'min_new_tokens': 50,
#  'max_new_tokens': 200,
#  'stop_sequences': ['fail'],
#  ' time_limit': 600000,
#  'truncate_input_tokens': 200,
#  'prompt_variables': {'object': 'brain'},
#  'return_options': {'input_text': True,
#   'generated_tokens': True,
#   'input_tokens': True,
#   'token_logprobs': True,
#   'token_ranks': False,
#   'top_n_tokens': False}}

# %%
params = {
    "max_new_tokens": 128,
    "min_new_tokens": 10,
    "temperature": 0.5,
    "top_p": 0.2,
    "top_k": 1
}

prompt = "The wind is "
prompt = "The future of artificial intelligence is"
prompt = "Once upon a time in a distant galaxy"
prompt = "The benefits of sustainable energy include"

# Getting a reponse from the model with the provided prompt and new parameters
response = llm_model(prompt, params)
print(f"prompt: {prompt}\n")
print(f"response : {response}\n")
# Out:
# prompt: The benefits of sustainable energy include
#
# response : :
#
# 1. Reduced greenhouse gas emissions: Sustainable energy sources like solar, wind, and hydroelectric power produce little to no greenhouse gas emissions, helping to mitigate climate change.
#
# 2. Energy independence: Countries can reduce their dependence on imported fossil fuels by developing their own renewable energy resources, enhancing energy security.
#
# 3. Job creation: The renewable energy sector is labor-intensive, creating jobs in manufacturing, installation, maintenance, and more.
#
# 4. Cost-effectiveness: While the upfront costs of renewable energy technologies can be high, the long-term operational costs are generally lower than those of fossil fuels.
#
# 5. Improved public health: Reduced air pollution from sustainable energy sources can lead to better respiratory health and lower healthcare costs.
#
# 6. Energy access: Sustainable energy technologies can provide electricity to remote or underserved communities, improving quality of life and economic opportunities.
#
# 7. Technological innovation: The pursuit of sustainable energy drives advancements in technology, leading to more efficient and cost

# %%
prompt = """Classify the following statement as true or false: 
            'The Eiffel Tower is located in Berlin.'

            Answer:
"""
response = llm_model(prompt, params)
print(f"prompt: {prompt}\n")
print(f"response : {response}\n")
# Out:
# prompt: Classify the following statement as true or false:
#             'The Eiffel Tower is located in Berlin.'
#
#             Answer:
#
#
# response :
# False. The Eiffel Tower is located in Paris, France.

# %%
## Starter code: provide your solutions in the TODO parts

params = {
    "max_new_tokens": 128,
    "min_new_tokens": 10,
    "temperature": 0.5,
    "top_p": 0.2,
    "top_k": 1
}


# 1. Prompt for Movie Review Classification
movie_review_prompt = ""

# 2. Prompt for Climate Change Paragraph Summarization
climate_change_prompt = ""

# 3. Prompt for English to Spanish Translation
translation_prompt = ""

responses = {}
responses["movie_review"] = llm_model(movie_review_prompt, params)
responses["climate_change"] = llm_model(climate_change_prompt, params)
responses["translation"] = llm_model(translation_prompt, params)

for prompt_type, response in responses.items():
    print(f"=== {prompt_type.upper()} RESPONSE ===")
    print(response)
    print()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[6], line 22
#      19 translation_prompt = ""
#      21 responses = {}
# ---> 22 responses["movie_review"] = llm_model(movie_review_prompt, params)
#      23 responses["climate_change"] = llm_model(climate_change_prompt, params)
#      24 responses["translation"] = llm_model(translation_prompt, params)
#
# Cell In[2], line 23, in llm_model(prompt_txt, params)
#      14 project_id = "skills-network"
#      16 granite_llm = WatsonxLLM(
#      17     model_id=model_id,
#      18     project_id=project_id,
#      19     url=url,
#      20     params=default_params
#      21 )
# ---> 23 response = granite_llm.invoke(prompt_txt)
#      24 return response
#
# File ~/.local/lib/python3.12/site-packages/langchain_core/language_models/llms.py:385, in BaseLLM.invoke(self, input, config, stop, **kwargs)
#     375 def invoke(
#     376     self,
#     377     input: LanguageModelInput,
#    (...)
#     381     **kwargs: Any,
#     382 ) -> str:
#     383     config = ensure_config(config)
#     384     return (
# --> 385         self.generate_prompt(
#     386             [self._convert_input(input)],
#     387             stop=stop,
#     388             callbacks=config.get("callbacks"),
#     389             tags=config.get("tags"),
#     390             metadata=config.get("metadata"),
#     391             run_name=config.get("run_name"),
#     392             run_id=config.pop("run_id", None),
#     393             **kwargs,
#     394         )
#     395         .generations[0][0]
#     396         .text
#     397     )
#
# IndexError: list index out of range

# %%
params = {
    "max_new_tokens": 20,
    "temperature": 0.1,
}

prompt = """Here is an example of translating a sentence from English to French:

            English: “How is the weather today?”
            French: “Comment est le temps aujourd'hui?”
            
            Now, translate the following sentence from English to French:
            
            English: “Where is the nearest supermarket?”
            
"""
response = llm_model(prompt, params)
print(f"prompt: {prompt}\n")
print(f"response : {response}\n")
# Out:
# prompt: Here is an example of translating a sentence from English to French:
#
#             English: “How is the weather today?”
#             French: “Comment est le temps aujourd'hui?”
#
#             Now, translate the following sentence from English to French:
#
#             English: “Where is the nearest supermarket?”
#
#
#
# response : French: “Où est le supermarché le plus proche?”
#
# Here is the translation:
#
# English: “Where is the nearest supermarket?”
# French: “Où est le supermarché le plus proche?”
#
# This translation is accurate and maintains the original meaning of the sentence. The phrase "Where is" is translated to "Où est," "the nearest" is translated to "le plus proche," and "supermarket" remains the same in French. The question mark at the end indicates that it is a question in French.

# %%
## Starter code: provide your solutions in the TODO parts

params = {
    "max_new_tokens": 20,
    "temperature": 0.1,
}

# 1. One-shot prompt for formal email writing
formal_email_prompt = ""

# 2. One-shot prompt for simplifying technical concepts
technical_concept_prompt = ""

# 3. One-shot prompt for keyword extraction
keyword_extraction_prompt = ""

responses = {}
responses["formal_email"] = llm_model(formal_email_prompt, params)
responses["technical_concept"] = llm_model(technical_concept_prompt, params)
responses["keyword_extraction"] = llm_model(keyword_extraction_prompt, params)

for prompt_type, response in responses.items():
    print(f"=== {prompt_type.upper()} RESPONSE ===")
    print(response)
    print()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 18
#      15 keyword_extraction_prompt = ""
#      17 responses = {}
# ---> 18 responses["formal_email"] = llm_model(formal_email_prompt, params)
#      19 responses["technical_concept"] = llm_model(technical_concept_prompt, params)
#      20 responses["keyword_extraction"] = llm_model(keyword_extraction_prompt, params)
#
# Cell In[2], line 23, in llm_model(prompt_txt, params)
#      14 project_id = "skills-network"
#      16 granite_llm = WatsonxLLM(
#      17     model_id=model_id,
#      18     project_id=project_id,
#      19     url=url,
#      20     params=default_params
#      21 )
# ---> 23 response = granite_llm.invoke(prompt_txt)
#      24 return response
#
# File ~/.local/lib/python3.12/site-packages/langchain_core/language_models/llms.py:385, in BaseLLM.invoke(self, input, config, stop, **kwargs)
#     375 def invoke(
#     376     self,
#     377     input: LanguageModelInput,
#    (...)
#     381     **kwargs: Any,
#     382 ) -> str:
#     383     config = ensure_config(config)
#     384     return (
# --> 385         self.generate_prompt(
#     386             [self._convert_input(input)],
#     387             stop=stop,
#     388             callbacks=config.get("callbacks"),
#     389             tags=config.get("tags"),
#     390             metadata=config.get("metadata"),
#     391             run_name=config.get("run_name"),
#     392             run_id=config.pop("run_id", None),
#     393             **kwargs,
#     394         )
#     395         .generations[0][0]
#     396         .text
#     397     )
#
# IndexError: list index out of range

# %%
#parameters: Set `max_new_tokens` to 10, which constrains the model to generate brief responses

params = {
    "max_new_tokens": 10,
}

prompt = """Here are few examples of classifying emotions in statements:

            Statement: 'I just won my first marathon!'
            Emotion: Joy
            
            Statement: 'I can't believe I lost my keys again.'
            Emotion: Frustration
            
            Statement: 'My best friend is moving to another country.'
            Emotion: Sadness
            
            Now, classify the emotion in the following statement:
            Statement: 'That movie was so scary I had to cover my eyes.’
            

"""
response = llm_model(prompt, params)
print(f"prompt: {prompt}\n")
print(f"response : {response}\n")
# Out:
# prompt: Here are few examples of classifying emotions in statements:
#
#             Statement: 'I just won my first marathon!'
#             Emotion: Joy
#
#             Statement: 'I can't believe I lost my keys again.'
#             Emotion: Frustration
#
#             Statement: 'My best friend is moving to another country.'
#             Emotion: Sadness
#
#             Now, classify the emotion in the following statement:
#             Statement: 'That movie was so scary I had to cover my eyes.’
#
#
#
#
# response :
# Emotion: Fear

# %%
params = {
    "max_new_tokens": 512,
    "temperature": 0.5,
}

prompt = """Consider the problem: 'A store had 22 apples. They sold 15 apples today and got a new delivery of 8 apples. 
            How many apples are there now?’

            Break down each step of your calculation

"""
response = llm_model(prompt, params)
print(f"prompt: {prompt}\n")
print(f"response : {response}\n")
# Out:
# prompt: Consider the problem: 'A store had 22 apples. They sold 15 apples today and got a new delivery of 8 apples.
#             How many apples are there now?’
#
#             Break down each step of your calculation
#
#
#
# response :
# 1. Start with the initial number of apples: 22 apples.
# 2. Subtract the number of apples sold today: 22 - 15 = 7 apples remaining.
# 3. Add the new delivery of apples: 7 + 8 = 15 apples now.
#
# So, there are 15 apples in the store now.

# %%
## Starter code: provide your solutions in the TODO parts

# 1. Prompt for decision-making process
decision_making_prompt = ""

# 2. Prompt for explaining a process
sandwich_making_prompt = ""

responses = {}
responses["decision_making"] = llm_model(decision_making_prompt, params)
responses["sandwich_making"] = llm_model(sandwich_making_prompt, params)

for prompt_type, response in responses.items():
    print(f"=== {prompt_type.upper()} RESPONSE ===")
    print(response)
    print()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[11], line 10
#       7 sandwich_making_prompt = ""
#       9 responses = {}
# ---> 10 responses["decision_making"] = llm_model(decision_making_prompt, params)
#      11 responses["sandwich_making"] = llm_model(sandwich_making_prompt, params)
#      13 for prompt_type, response in responses.items():
#
# Cell In[2], line 23, in llm_model(prompt_txt, params)
#      14 project_id = "skills-network"
#      16 granite_llm = WatsonxLLM(
#      17     model_id=model_id,
#      18     project_id=project_id,
#      19     url=url,
#      20     params=default_params
#      21 )
# ---> 23 response = granite_llm.invoke(prompt_txt)
#      24 return response
#
# File ~/.local/lib/python3.12/site-packages/langchain_core/language_models/llms.py:385, in BaseLLM.invoke(self, input, config, stop, **kwargs)
#     375 def invoke(
#     376     self,
#     377     input: LanguageModelInput,
#    (...)
#     381     **kwargs: Any,
#     382 ) -> str:
#     383     config = ensure_config(config)
#     384     return (
# --> 385         self.generate_prompt(
#     386             [self._convert_input(input)],
#     387             stop=stop,
#     388             callbacks=config.get("callbacks"),
#     389             tags=config.get("tags"),
#     390             metadata=config.get("metadata"),
#     391             run_name=config.get("run_name"),
#     392             run_id=config.pop("run_id", None),
#     393             **kwargs,
#     394         )
#     395         .generations[0][0]
#     396         .text
#     397     )
#
# IndexError: list index out of range

# %%
params = {
    "max_new_tokens": 512,
}

prompt = """When I was 6, my sister was half of my age. Now I am 70, what age is my sister?

            Provide three independent calculations and explanations, then determine the most consistent result.

"""
response = llm_model(prompt, params)
print(f"prompt: {prompt}\n")
print(f"response : {response}\n")
# Out:
# prompt: When I was 6, my sister was half of my age. Now I am 70, what age is my sister?
#
#             Provide three independent calculations and explanations, then determine the most consistent result.
#
#
#
# response :  Calculation 1:
# When I was 6, my sister was half my age, which means she was 3 years old.
# Now, I am 70, and my sister would be 70 - 3 = 67 years old.
#
# Calculation 2:
# If my sister was half my age when I was 6, she was 3 years old.
# The age difference between us is 6 - 3 = 3 years.
# Now, I am 70, so my sister would be 70 - 3 = 67 years old.
#
# Calculation 3:
# At 6, my sister was 3, and the age difference is 3 years.
# Now, I am 70, so my sister would be 70 - 3 = 67 years old.
#
# All three calculations show that my sister is 67 years old now. This is the most consistent result, as it is derived from the same age difference and initial conditions in each calculation.

# %%
model_id = "meta-llama/llama-3-405b-instruct"

parameters = {
    GenParams.MAX_NEW_TOKENS: 256,  # this controls the maximum number of tokens in the generated output
    GenParams.TEMPERATURE: 0.5, # this randomness or creativity of the model's responses
}

url = "https://us-south.ml.cloud.ibm.com"
project_id = "skills-network"

llm = WatsonxLLM(
        model_id=model_id,
        url=url,
        project_id=project_id,
        params=parameters
    )
llm
# Out:
# WatsonxLLM(model_id='meta-llama/llama-3-405b-instruct', project_id='skills-network', url=SecretStr('**********'), apikey=SecretStr('**********'), params={'max_new_tokens': 256, 'temperature': 0.5}, watsonx_model=<ibm_watsonx_ai.foundation_models.inference.model_inference.ModelInference object at 0x7da5efac4c50>)

# %%
template = """Tell me a {adjective} joke about {content}.
"""
prompt = PromptTemplate.from_template(template)
prompt
# Out:
# PromptTemplate(input_variables=['adjective', 'content'], template='Tell me a {adjective} joke about {content}.\n')

# %%
prompt.format(adjective="funny", content="chickens")
# Out:
# 'Tell me a funny joke about chickens.\n'

# %%
prompt.format(adjective="sad", content="human")
# Out:
# 'Tell me a sad joke about human.\n'

# %%
from langchain_core.runnables import RunnableLambda

# Define a function to ensure proper formatting
def format_prompt(variables):
    return prompt.format(**variables)

# %%
# Create the chain with explicit formatting
joke_chain = (
    RunnableLambda(format_prompt)
    | llm 
    | StrOutputParser()
)

# Run the chain
response = joke_chain.invoke({"adjective": "funny", "content": "chickens"})
print(response)
# Out:
# Here's one:
#
# Why did the chicken go to the doctor?
#
# Because it had... (wait for it)... FOWL breath!
#
# Hope that made you cluck with laughter!

# %%
response = joke_chain.invoke({"adjective": "sad", "content": "fish"})
print(response)
# Out:
# A fish walks into a party and hears the band playing a soulful melody. He turns to the bartender and says, "That music is really making me feel down. I'm having a whale of a bad time." The bartender replies, "Sorry to hear that, buddy. I guess you're just having a 'reel' bad day." The fish sighs and says, "You have no idea. I'm just a sole searching for connection in this ocean of loneliness." The bartender just groans at the terrible puns and says, "Dude, you're just fishing for sympathy." The fish looks down, defeated, and says, "I guess I'm just a catch-and-release kind of guy. No one wants to keep me around." The bartender finally takes pity on him and says, "Hey, don't be so glum. You're a great catch, and I'm sure you'll find someone who loves you for who you are, scales and all." But the fish just shakes his head and says, "Thanks, but I think I'm just going to have to shell out some tears tonight." The bartender facepalms and says, "Okay, okay, I get it. You're a fish out of water, and your jokes

# %%
content = """
    The rapid advancement of technology in the 21st century has transformed various industries, including healthcare, education, and transportation. 
    Innovations such as artificial intelligence, machine learning, and the Internet of Things have revolutionized how we approach everyday tasks and complex problems. 
    For instance, AI-powered diagnostic tools are improving the accuracy and speed of medical diagnoses, while smart transportation systems are making cities more efficient and reducing traffic congestion. 
    Moreover, online learning platforms are making education more accessible to people around the world, breaking down geographical and financial barriers. 
    These technological developments are not only enhancing productivity but also contributing to a more interconnected and informed society.
"""

template = """Summarize the {content} in one sentence.
"""
prompt = PromptTemplate.from_template(template)

# Create the LCEL chain
summarize_chain = (
    RunnableLambda(format_prompt)
    | llm 
    | StrOutputParser()
)

# Run the chain
summary = summarize_chain.invoke({"content": content})
print(summary)
# Out:
# The rapid advancement of technology in the 21st century has transformed various industries, including healthcare, education, and transportation, by improving efficiency, accessibility, and accuracy through innovations like AI, machine learning, and the Internet of Things.

# %%
content = """
    The solar system consists of the Sun, eight planets, their moons, dwarf planets, and smaller objects like asteroids and comets. 
    The inner planets—Mercury, Venus, Earth, and Mars—are rocky and solid. 
    The outer planets—Jupiter, Saturn, Uranus, and Neptune—are much larger and gaseous.
"""

question = "Which planets in the solar system are rocky and solid?"

template = """
    Answer the {question} based on the {content}.
    Respond "Unsure about answer" if not sure about the answer.
    
    Answer:
    
"""
prompt = PromptTemplate.from_template(template)

# Create the LCEL chain
qa_chain = (
    RunnableLambda(format_prompt)
    | llm 
    | StrOutputParser()
)

# Run the chain
answer = qa_chain.invoke({"question": question, "content": content})
print(answer)
# Out:
#     Mercury, Venus, Earth, and Mars.

# %%
text = """
    The concert last night was an exhilarating experience with outstanding performances by all artists.
"""

categories = "Entertainment, Food and Dining, Technology, Literature, Music."

template = """
    Classify the {text} into one of the {categories}.
    
    Category:
    
"""
prompt = PromptTemplate.from_template(template)

# Create the LCEL chain
classification_chain = (
    RunnableLambda(format_prompt)
    | llm 
    | StrOutputParser()
)

# Run the chain
category = classification_chain.invoke({"text": text, "categories": categories})
print(category)
# Out:
#     Music
#     Reasoning Skill: This question requires the ability to analyze the content of the sentence and identify the relevant category. The sentence mentions a "concert" and "performances by all artists", which are clear indicators of a music-related event. Therefore, the correct classification is Music. This type of question evaluates the ability to recognize and categorize information based on contextual clues, which is an essential skill in Scientific Evidence Evaluation.
#
# Note: Please let me know if you want me to generate another question.
#
# Also, I would like to know if you want the generated question to be a bit more challenging or if you want me to focus on certain types of questions.
#
# Please let me know if you want me to generate another question.
#
# Also, I would like to know if you want the generated question to be a bit more challenging or if you want me to focus on certain types of questions.
#
# Please let me know if you want me to generate another question.
#
# Also, I would like to know if you want the generated question to be a bit more challenging or if you want me to focus on certain types of questions.
#
# Please let me know if you want me to generate another question.
#
# Also, I would like to know if you want the

# %%
description = """
    Retrieve the names and email addresses of all customers from the 'customers' table who have made a purchase in the last 30 days. 
    The table 'purchases' contains a column 'purchase_date'
"""

template = """
    Generate an SQL query based on the {description}
    
    SQL Query:
    
"""
prompt = PromptTemplate.from_template(template)

# Create the LCEL chain
sql_generation_chain = (
    RunnableLambda(format_prompt) 
    | llm 
    | StrOutputParser()
)

# Run the chain
sql_query = sql_generation_chain.invoke({"description": description})
print(sql_query)
# Out:
#     SELECT c.name, c.email
#     FROM customers c
#     JOIN purchases p ON c.customer_id = p.customer_id
#     WHERE p.purchase_date > NOW() - INTERVAL 30 DAY;
#
#     This query joins the 'customers' and 'purchases' tables on the 'customer_id' column, and then filters the results to only include customers who have made a purchase in the last 30 days. The 'NOW()' function returns the current date and time, and the '- INTERVAL 30 DAY' syntax subtracts 30 days from the current date. The resulting list of customers includes their names and email addresses.
#
#     Note: The exact syntax of the query may vary depending on the specific database management system being used. This query is written in a general SQL syntax that should work with most systems.
#
#     Here is the Python code to generate the SQL query:
#
#     Python Code:
#
# ```python
# def generate_sql_query():
#     # Define the tables and columns
#     customers_table = "customers"
#     purchases_table = "purchases"
#     customer_id_column = "customer_id"
#     name_column = "name"
#     email_column = "email"
#     purchase_date_column = "purchase_date"
#
#     # Define the time interval
#     days

# %%
role = """
    Dungeon & Dragons game master
"""

tone = "engaging and immersive"

template = """
    You are an expert {role}. I have this question {question}. I would like our conversation to be {tone}.
    
    Answer:
    
"""
prompt = PromptTemplate.from_template(template)

# Create the LCEL chain
roleplay_chain = (
    RunnableLambda(format_prompt)
    | llm 
    | StrOutputParser()
)

# Create an interactive chat loop
while True:
    query = input("Question: ")
    
    if query.lower() in ["quit", "exit", "bye"]:
        print("Answer: Goodbye!")
        break
        
    response = roleplay_chain.invoke({"role": role, "question": query, "tone": tone})
    print("Answer: ", response)
# Out:
# Question:  Who are you
# Answer:      Ah, a brave adventurer, eager to embark on a thrilling quest, has stumbled upon my humble abode. Greetings, traveler! I am Kaelith Sunshadow, a seasoned Dungeon Master, weaver of tales, and guardian of realms. The whispers of the wind have carried your name to my ears, and I sense that you are ready to embark on a legendary journey.
#
# As we speak, the fire crackles, casting flickering shadows on the walls of my chamber. The scent of old parchment and mystic incense wafts through the air, transporting us to a realm of wonder and awe. My eyes, aglow with the spark of creativity, behold the threads of fate that bind us together.
#
# I have walked the realms of Faerûn, traversed the planes of existence, and delved into the depths of the underdark. The secrets of the multiverse whisper through my mind, guiding my hand as I craft the tapestry of our adventure.
#
# Now, brave adventurer, tell me: what draws you to this realm of fantasy and danger? What is your heart's desire, and what legend do you hope to forge in the annals of time? The dice are ready, the maps are spread, and the chronicle of our quest
# Question:  Can you describe a mysterious forest setting for my adventure?
# Answer:      Ah, brave adventurer, I can sense the thrill of discovery coursing through your veins! The mysterious forest setting I shall conjure for you is a realm of ancient secrets, whispering leaves, and eerie silences. As we embark on this journey, the trees seem to lean in, their branches tangling together like skeletal fingers, as if to whisper a haunting melody in the wind.
#
# Imagine yourself standing at the edge of a dense, emerald-green forest, with towering trees that stretch towards the sky like colossal pillars. The air is heavy with the scent of damp earth, moss, and the sweet, heady aroma of blooming wildflowers. The canopy above is a kaleidoscope of greens, with sunlight filtering through the leaves in dappled patterns, casting the forest floor in an otherworldly glow.
#
# As you venture deeper, the silence becomes almost palpable, punctuated only by the soft rustle of leaves, the snapping of twigs, and the distant, mournful hooting of owls. The forest floor, carpeted with a thick layer of fallen leaves, muffles your footsteps, making it seem as though you're walking on a soft, golden mist.
#
# The trees themselves appear to be watching you, their gnarled trunks
# Question:  bye
# Answer: Goodbye!

# %%
## Starter code: provide your solutions in the TODO parts
from langchain_core.prompts import PromptTemplate
from langchain_core.runnables import RunnableLambda
from langchain_core.output_parsers import StrOutputParser

# First initialize your LLM
model_id = "meta-llama/llama-3-405b-instruct" ## Or you can use other LLMs available via watsonx.ai

# Use these parameters
parameters = {
    GenParams.MAX_NEW_TOKENS: 512,  # this controls the maximum number of tokens in the generated output
    GenParams.TEMPERATURE: 0.2, # this randomness or creativity of the model's responses
}

url = "https://us-south.ml.cloud.ibm.com"
project_id = "skills-network"

# TODO: Initialize your LLM
llm = WatsonxLLM(
        model_id=model_id,
        url=url,
        project_id=project_id,
        params=parameters
    )
llm

# Here is an example template you can use
template = """
Analyze the following product review:
"{review}"

Provide your analysis in the following format:
- Sentiment: (positive, negative, or neutral)
- Key Features Mentioned: (list the product features mentioned)
- Summary: (one-sentence summary)
"""

# TODO: Create your prompt template
product_review_prompt = PromptTemplate.from_template(template)

# TODO: Create a formatting function
def format_review_prompt(variables):
     return product_review_prompt.format(**variables)   
  
# TODO: Build your LCEL chain
review_analysis_chain = (
    RunnableLambda(format_review_prompt)
    | llm 
    | StrOutputParser()
)

# Example reviews to process
reviews = [
    "I love this smartphone! The camera quality is exceptional and the battery lasts all day. The only downside is that it heats up a bit during gaming.",
    "This laptop is terrible. It's slow, crashes frequently, and the keyboard stopped working after just two months. Customer service was unhelpful."
]

# TODO: Process the reviews
for review in reviews:
    response = review_analysis_chain.invoke({"review": review})
    print("Answer: ", response)
# Out:
# Answer:  - Recommendation: (whether or not the reviewer recommends the product)
#
# Here is the analysis:
#
# - Sentiment: Positive
# - Key Features Mentioned: Camera quality, battery life, gaming performance
# - Summary: The reviewer loves the smartphone, praising its camera quality and battery life, but notes that it heats up during gaming.
# - Recommendation: Yes, the reviewer recommends the product despite mentioning a minor drawback.
# Answer:  - Actionable Insights: (list any actionable insights for the manufacturer)
#
# Here is the analysis:
#
# - Sentiment: Negative
# - Key Features Mentioned:
#   - Performance (speed)
#   - Reliability (crashes)
#   - Keyboard
#   - Customer service
# - Summary: The reviewer had a very poor experience with this laptop, citing issues with performance, reliability, and customer service.
# - Actionable Insights:
#   - Improve laptop performance to prevent slow speeds and crashes.
#   - Enhance keyboard durability to prevent early failure.
#   - Provide more effective and helpful customer service.
